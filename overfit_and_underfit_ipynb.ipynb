# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.8.0

# %%
# !pip install git+https://github.com/tensorflow/docs

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-8x4hyy_9
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-8x4hyy_9
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (1.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (2.11.3)
# Requirement already satisfied: protobuf>=3.14 in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (3.17.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (3.13)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.14->tensorflow-docs==0.0.0.dev0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->tensorflow-docs==0.0.0.dev0) (2.0.1)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0.dev0-py3-none-any.whl size=179546 sha256=dab6b3d71d2ecf4c45496b12673a953638f1dfecc8fbdce9d617f2987cb76c49
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8uy1_6oy/wheels/cc/c4/d8/5341e93b6376c5c929c49469fce21155eb69cef1a4da4ce32c
# Successfully built tensorflow-docs
# Installing collected packages: tensorflow-docs
# Successfully installed tensorflow-docs-0.0.0.dev0

# %%
from IPython import display
from matplotlib import pyplot as plt

import pathlib 
import shutil
import tempfile
import numpy as np

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %% [markdown]
# The Higgs dataset

# %%
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')
# Out:
# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz
# 2816409600/2816407858 [==============================] - 54s 0us/step
# 2816417792/2816407858 [==============================] - 54s 0us/step

# %%
FEATURES = 28

# %%
ds = tf.data.experimental.CsvDataset(gz, [float(),]*(FEATURES+1), compression_type='GZIP')

# %%
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

# %%
packed_row = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_row.batch(1000).take(1):
  print(features[0])
  plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_row.take(N_VALIDATION).cache()
train_ds = packed_row.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset element_spec=(TensorSpec(shape=(28,), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.float32, name=None))>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %% [markdown]
# Demonstrate overfitting

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    0.001,
    decay_steps=STEPS_PER_EPOCH*1000,
    decay_rate=1,
    staircase=False
)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %% [markdown]
# Tiny **Model**

# %%
tiny_model = tf.keras.Sequential([
                                  layers.Dense(16, activation='relu', input_shape=(FEATURES,)),
                                  layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny']= compile_and_fit(tiny_model,'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                464
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4906,  binary_crossentropy:0.7775,  loss:0.7775,  val_accuracy:0.4750,  val_binary_crossentropy:0.7654,  val_loss:0.7654,
# ....................................................................................................
# Epoch: 100, accuracy:0.6039,  binary_crossentropy:0.6228,  loss:0.6228,  val_accuracy:0.5690,  val_binary_crossentropy:0.6288,  val_loss:0.6288,
# ....................................................................................................
# Epoch: 200, accuracy:0.6355,  binary_crossentropy:0.6041,  loss:0.6041,  val_accuracy:0.6200,  val_binary_crossentropy:0.6127,  val_loss:0.6127,
# ....................................................................................................
# Epoch: 300, accuracy:0.6591,  binary_crossentropy:0.5905,  loss:0.5905,  val_accuracy:0.6350,  val_binary_crossentropy:0.5989,  val_loss:0.5989,
# ....................................................................................................
# Epoch: 400, accuracy:0.6769,  binary_crossentropy:0.5834,  loss:0.5834,  val_accuracy:0.6370,  val_binary_crossentropy:0.5944,  val_loss:0.5944,
# ....................................................................................................
# Epoch: 500, accuracy:0.6741,  binary_crossentropy:0.5807,  loss:0.5807,  val_accuracy:0.6490,  val_binary_crossentropy:0.5918,  val_loss:0.5918,
# ....................................................................................................
# Epoch: 600, accuracy:0.6770,  binary_crossentropy:0.5777,  loss:0.5777,  val_accuracy:0.6440,  val_binary_crossentropy:0.5901,  val_loss:0.5901,
# ....................................................................................................
# Epoch: 700, accuracy:0.6796,  binary_crossentropy:0.5750,  loss:0.5750,  val_accuracy:0.6550,  val_binary_crossentropy:0.5863,  val_loss:0.5863,
# ....................................................................................................
# Epoch: 800, accuracy:0.6835,  binary_crossentropy:0.5733,  loss:0.5733,  val_accuracy:0.6520,  val_binary_crossentropy:0.5856,  val_loss:0.5856,
# ....................................................................................................
# Epoch: 900, accuracy:0.6856,  binary_crossentropy:0.5713,  loss:0.5713,  val_accuracy:0.6520,  val_binary_crossentropy:0.5850,  val_loss:0.5850,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6853,  binary_crossentropy:0.5699,  loss:0.5699,  val_accuracy:0.6580,  val_binary_crossentropy:0.5837,  val_loss:0.5837,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6869,  binary_crossentropy:0.5690,  loss:0.5690,  val_accuracy:0.6530,  val_binary_crossentropy:0.5853,  val_loss:0.5853,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6863,  binary_crossentropy:0.5678,  loss:0.5678,  val_accuracy:0.6590,  val_binary_crossentropy:0.5832,  val_loss:0.5832,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6903,  binary_crossentropy:0.5672,  loss:0.5672,  val_accuracy:0.6570,  val_binary_crossentropy:0.5822,  val_loss:0.5822,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6913,  binary_crossentropy:0.5666,  loss:0.5666,  val_accuracy:0.6610,  val_binary_crossentropy:0.5831,  val_loss:0.5831,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6902,  binary_crossentropy:0.5659,  loss:0.5659,  val_accuracy:0.6660,  val_binary_crossentropy:0.5821,  val_loss:0.5821,
# .......................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %% [markdown]
# Small Model

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 16)                464
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4994,  binary_crossentropy:0.7193,  loss:0.7193,  val_accuracy:0.5120,  val_binary_crossentropy:0.7031,  val_loss:0.7031,
# ....................................................................................................
# Epoch: 100, accuracy:0.6097,  binary_crossentropy:0.6169,  loss:0.6169,  val_accuracy:0.6040,  val_binary_crossentropy:0.6219,  val_loss:0.6219,
# ....................................................................................................
# Epoch: 200, accuracy:0.6382,  binary_crossentropy:0.5999,  loss:0.5999,  val_accuracy:0.6260,  val_binary_crossentropy:0.6113,  val_loss:0.6113,
# ....................................................................................................
# Epoch: 300, accuracy:0.6594,  binary_crossentropy:0.5868,  loss:0.5868,  val_accuracy:0.6510,  val_binary_crossentropy:0.5990,  val_loss:0.5990,
# ....................................................................................................
# Epoch: 400, accuracy:0.6698,  binary_crossentropy:0.5769,  loss:0.5769,  val_accuracy:0.6540,  val_binary_crossentropy:0.5943,  val_loss:0.5943,
# ....................................................................................................
# Epoch: 500, accuracy:0.6815,  binary_crossentropy:0.5715,  loss:0.5715,  val_accuracy:0.6590,  val_binary_crossentropy:0.5929,  val_loss:0.5929,
# ....................................................................................................
# Epoch: 600, accuracy:0.6821,  binary_crossentropy:0.5687,  loss:0.5687,  val_accuracy:0.6600,  val_binary_crossentropy:0.5914,  val_loss:0.5914,
# ....................................................................................................
# Epoch: 700, accuracy:0.6882,  binary_crossentropy:0.5647,  loss:0.5647,  val_accuracy:0.6580,  val_binary_crossentropy:0.5924,  val_loss:0.5924,
# ....................................................................................................
# Epoch: 800, accuracy:0.6926,  binary_crossentropy:0.5628,  loss:0.5628,  val_accuracy:0.6570,  val_binary_crossentropy:0.5916,  val_loss:0.5916,
# ....................................................................................................
# Epoch: 900, accuracy:0.6932,  binary_crossentropy:0.5597,  loss:0.5597,  val_accuracy:0.6590,  val_binary_crossentropy:0.5907,  val_loss:0.5907,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6938,  binary_crossentropy:0.5570,  loss:0.5570,  val_accuracy:0.6660,  val_binary_crossentropy:0.5884,  val_loss:0.5884,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6961,  binary_crossentropy:0.5555,  loss:0.5555,  val_accuracy:0.6680,  val_binary_crossentropy:0.5874,  val_loss:0.5874,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6992,  binary_crossentropy:0.5536,  loss:0.5536,  val_accuracy:0.6610,  val_binary_crossentropy:0.5889,  val_loss:0.5889,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6997,  binary_crossentropy:0.5514,  loss:0.5514,  val_accuracy:0.6620,  val_binary_crossentropy:0.5882,  val_loss:0.5882,
# ....................................................................................................
# Epoch: 1400, accuracy:0.7007,  binary_crossentropy:0.5499,  loss:0.5499,  val_accuracy:0.6610,  val_binary_crossentropy:0.5886,  val_loss:0.5886,
# ....................................................................................................
# Epoch: 1500, accuracy:0.7014,  binary_crossentropy:0.5494,  loss:0.5494,  val_accuracy:0.6620,  val_binary_crossentropy:0.5894,  val_loss:0.5894,
# ..............

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                1856
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5001,  binary_crossentropy:0.6982,  loss:0.6982,  val_accuracy:0.5030,  val_binary_crossentropy:0.6787,  val_loss:0.6787,
# ....................................................................................................
# Epoch: 100, accuracy:0.7151,  binary_crossentropy:0.5300,  loss:0.5300,  val_accuracy:0.6560,  val_binary_crossentropy:0.6022,  val_loss:0.6022,
# ....................................................................................................
# Epoch: 200, accuracy:0.7834,  binary_crossentropy:0.4322,  loss:0.4322,  val_accuracy:0.6490,  val_binary_crossentropy:0.6938,  val_loss:0.6938,
# .....................................................................

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %% [markdown]
# Strategies to prevent overfitting

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# PosixPath('/tmp/tmpb10u01nq/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               14848
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 512)               262656
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dense_13 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5104,  binary_crossentropy:0.7568,  loss:2.2555,  val_accuracy:0.5410,  val_binary_crossentropy:0.6620,  val_loss:2.0674,
# ....................................................................................................
# Epoch: 100, accuracy:0.6548,  binary_crossentropy:0.5967,  loss:0.6203,  val_accuracy:0.6670,  val_binary_crossentropy:0.5838,  val_loss:0.6072,
# ....................................................................................................
# Epoch: 200, accuracy:0.6709,  binary_crossentropy:0.5833,  loss:0.6059,  val_accuracy:0.6740,  val_binary_crossentropy:0.5827,  val_loss:0.6050,
# ....................................................................................................
# Epoch: 300, accuracy:0.6824,  binary_crossentropy:0.5745,  loss:0.5968,  val_accuracy:0.6600,  val_binary_crossentropy:0.5808,  val_loss:0.6028,
# ....................................................................................................
# Epoch: 400, accuracy:0.6811,  binary_crossentropy:0.5725,  loss:0.5936,  val_accuracy:0.6690,  val_binary_crossentropy:0.5794,  val_loss:0.6005,
# ...................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
result = l2_model(features)
regularization_loss=tf.add_n(l2_model.losses)

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 512)               14848
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_15 (Dense)            (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_16 (Dense)            (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_17 (Dense)            (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4886,  binary_crossentropy:0.8332,  loss:0.8332,  val_accuracy:0.4850,  val_binary_crossentropy:0.6775,  val_loss:0.6775,
# ....................................................................................................
# Epoch: 100, accuracy:0.6593,  binary_crossentropy:0.5951,  loss:0.5951,  val_accuracy:0.6700,  val_binary_crossentropy:0.5799,  val_loss:0.5799,
# ....................................................................................................
# Epoch: 200, accuracy:0.6882,  binary_crossentropy:0.5573,  loss:0.5573,  val_accuracy:0.6840,  val_binary_crossentropy:0.5894,  val_loss:0.5894,
# ....................................................................................................
# Epoch: 300, accuracy:0.7127,  binary_crossentropy:0.5149,  loss:0.5149,  val_accuracy:0.6720,  val_binary_crossentropy:0.6166,  val_loss:0.6166,
# ................................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 512)               14848
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_21 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_22 (Dense)            (None, 512)               262656
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_23 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5052,  binary_crossentropy:0.7882,  loss:0.9464,  val_accuracy:0.5330,  val_binary_crossentropy:0.6826,  val_loss:0.8402,
# ....................................................................................................
# Epoch: 100, accuracy:0.6536,  binary_crossentropy:0.6016,  loss:0.6310,  val_accuracy:0.6680,  val_binary_crossentropy:0.5812,  val_loss:0.6104,
# ....................................................................................................
# Epoch: 200, accuracy:0.6650,  binary_crossentropy:0.5911,  loss:0.6168,  val_accuracy:0.6670,  val_binary_crossentropy:0.5754,  val_loss:0.6012,
# ....................................................................................................
# Epoch: 300, accuracy:0.6698,  binary_crossentropy:0.5828,  loss:0.6112,  val_accuracy:0.6530,  val_binary_crossentropy:0.5774,  val_loss:0.6059,
# ....................................................................................................
# Epoch: 400, accuracy:0.6784,  binary_crossentropy:0.5733,  loss:0.6035,  val_accuracy:0.6870,  val_binary_crossentropy:0.5597,  val_loss:0.5900,
# ....................................................................................................
# Epoch: 500, accuracy:0.6878,  binary_crossentropy:0.5685,  loss:0.6009,  val_accuracy:0.6840,  val_binary_crossentropy:0.5597,  val_loss:0.5920,
# ....................................................................................................
# Epoch: 600, accuracy:0.6890,  binary_crossentropy:0.5627,  loss:0.5969,  val_accuracy:0.6870,  val_binary_crossentropy:0.5507,  val_loss:0.5850,
# ....................................................................................................
# Epoch: 700, accuracy:0.6948,  binary_crossentropy:0.5595,  loss:0.5954,  val_accuracy:0.6840,  val_binary_crossentropy:0.5520,  val_loss:0.5880,
# ....................................................................................................
# Epoch: 800, accuracy:0.6948,  binary_crossentropy:0.5599,  loss:0.5978,  val_accuracy:0.6890,  val_binary_crossentropy:0.5438,  val_loss:0.5817,
# ....................................................................................................
# Epoch: 900, accuracy:0.6931,  binary_crossentropy:0.5567,  loss:0.5961,  val_accuracy:0.6790,  val_binary_crossentropy:0.5491,  val_loss:0.5884,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6963,  binary_crossentropy:0.5488,  loss:0.5896,  val_accuracy:0.6900,  val_binary_crossentropy:0.5476,  val_loss:0.5884,
# ....................................................................................................
# Epoch: 1100, accuracy:0.7020,  binary_crossentropy:0.5472,  loss:0.5893,  val_accuracy:0.6990,  val_binary_crossentropy:0.5514,  val_loss:0.5935,
# ....................................................................................................
# Epoch: 1200, accuracy:0.7001,  binary_crossentropy:0.5482,  loss:0.5914,  val_accuracy:0.6940,  val_binary_crossentropy:0.5494,  val_loss:0.5926,
# ...

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)
